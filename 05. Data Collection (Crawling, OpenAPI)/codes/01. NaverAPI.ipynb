# %% [markdown]
# # 네이버 API를 활용한 검색 데이터 가져오기

# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

# %%
def clean_html(x):
  #https://predictor-ver1.tistory.com/4
  x = re.sub("\&\w*\;","",x)
  x = re.sub("<.*?>","",x)
  return x

# %%
client_id = "8sAydq_QSOxKcICuD2Og" #발급받은 ID 입력
client_secret = "OruQjbmaXF" #발급받은 PW 입력
encText = urllib.parse.quote("리니지") # 검색할 단어 입력
url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    #print(result)
else:
    print("Error Code:" + rescode)

# %%
result_json = json.loads(result)

# %%
df_json = pd.DataFrame(result_json["items"])

# %%
df_json
# Out:
#                                           title  \
# 0   &quot;공정위로 가자&quot; 게임 운영 불만에 게이머 너도나도 집단행동
# 1              엔씨소프트, AI 연구·개발 게임에 활용하자 주가 '펄펄'
# 2                          웹젠, 파나나스튜디오에 50억원 투자
# 3    웹젠, 파나나스튜디오에 50억원 투자…&quot;우수 개발사 확보&quot;
# 4                         웹젠, ‘파나나스튜디오’에 50억 투자
# 5               웹젠, 신생 게임 개발사 ‘파나나스튜디오’에 50억 투자
# 6                웹젠, 파나나스튜디오에 50억원 투자…우수 개발사 확보
# 7               웹젠, 신생 게임 개발사 ‘파나나스튜디오’에 50억 투자
# 8                         웹젠, '파나나스튜디오'에 50억 투자
# 9  웹젠, 게임개발사 ‘파나나스튜디오’에 50억 투자… ‘프로젝트 세일러’ 퍼...
#
#                                         originallink  \
# 0  https://www.yna.co.kr/view/AKR2024032611000001...
# 1            https://cwn.kr/article/1065591743398783
# 2  https://www.tgdaily.co.kr/news/articleView.htm...
# 3  https://biz.sbs.co.kr/article_hub/20000163359?...
# 4  http://www.lawissue.co.kr/view.php?ud=20240326...
# 5  http://www.gameshot.net/common/con_view.php?co...
# 6  https://biz.chosun.com/it-science/ict/2024/03/...
# 7                  https://kbench.com/?q=node/254240
# 8  http://www.newstomato.com/ReadNews.aspx?no=122...
# 9  https://www.ceoscoredaily.com/page/view/202403...
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/001/001...
# 1            https://cwn.kr/article/1065591743398783
# 2  https://www.tgdaily.co.kr/news/articleView.htm...
# 3  https://n.news.naver.com/mnews/article/374/000...
# 4  http://www.lawissue.co.kr/view.php?ud=20240326...
# 5  http://www.gameshot.net/common/con_view.php?co...
# 6  https://n.news.naver.com/mnews/article/366/000...
# 7                  https://kbench.com/?q=node/254240
# 8  http://www.newstomato.com/ReadNews.aspx?no=122...
# 9  https://www.ceoscoredaily.com/page/view/202403...
#
#                                          description  \
# 0  라그나로크·<b>리니지</b> 이용자 단체 민원…&quot;메이플 사태로 소비자 의...
# 1  PC게임 <b>리니지</b>와 <b>리니지</b>2, 아이온, 블레이드앤소울, 길드...
# 2  파나나스튜디오에는 텐센트코리아의 사업개발이사 등을 역임한 강일모 대표를 중심으로 '...
# 3  파나나스튜디오에는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으...
# 4  이어 &quot;파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대...
# 5  파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으로...
# 6  파나나스튜디오는 텐센트코리아에서 사업개발 이사를 역임한 강일모 대표를 중심으로 <b...
# 7  파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으로...
# 8  (사진=웹젠) 파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표...
# 9  파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으로...
#
#                            pubDate
# 0  Tue, 26 Mar 2024 14:52:00 +0900
# 1  Tue, 26 Mar 2024 14:46:00 +0900
# 2  Tue, 26 Mar 2024 14:44:00 +0900
# 3  Tue, 26 Mar 2024 14:24:00 +0900
# 4  Tue, 26 Mar 2024 14:24:00 +0900
# 5  Tue, 26 Mar 2024 14:16:00 +0900
# 6  Tue, 26 Mar 2024 14:01:00 +0900
# 7  Tue, 26 Mar 2024 13:46:00 +0900
# 8  Tue, 26 Mar 2024 13:42:00 +0900
# 9  Tue, 26 Mar 2024 13:36:00 +0900

# %%
df_json['title'] = df_json['title'].apply(lambda x: clean_html(x))
df_json['description'] = df_json['description'].apply(lambda x: clean_html(x))

# %%
df_json
# Out:
#                                           title  \
# 0               공정위로 가자 게임 운영 불만에 게이머 너도나도 집단행동
# 1              엔씨소프트, AI 연구·개발 게임에 활용하자 주가 '펄펄'
# 2                          웹젠, 파나나스튜디오에 50억원 투자
# 3                웹젠, 파나나스튜디오에 50억원 투자…우수 개발사 확보
# 4                         웹젠, ‘파나나스튜디오’에 50억 투자
# 5               웹젠, 신생 게임 개발사 ‘파나나스튜디오’에 50억 투자
# 6                웹젠, 파나나스튜디오에 50억원 투자…우수 개발사 확보
# 7               웹젠, 신생 게임 개발사 ‘파나나스튜디오’에 50억 투자
# 8                         웹젠, '파나나스튜디오'에 50억 투자
# 9  웹젠, 게임개발사 ‘파나나스튜디오’에 50억 투자… ‘프로젝트 세일러’ 퍼...
#
#                                         originallink  \
# 0  https://www.yna.co.kr/view/AKR2024032611000001...
# 1            https://cwn.kr/article/1065591743398783
# 2  https://www.tgdaily.co.kr/news/articleView.htm...
# 3  https://biz.sbs.co.kr/article_hub/20000163359?...
# 4  http://www.lawissue.co.kr/view.php?ud=20240326...
# 5  http://www.gameshot.net/common/con_view.php?co...
# 6  https://biz.chosun.com/it-science/ict/2024/03/...
# 7                  https://kbench.com/?q=node/254240
# 8  http://www.newstomato.com/ReadNews.aspx?no=122...
# 9  https://www.ceoscoredaily.com/page/view/202403...
#
#                                                 link  \
# 0  https://n.news.naver.com/mnews/article/001/001...
# 1            https://cwn.kr/article/1065591743398783
# 2  https://www.tgdaily.co.kr/news/articleView.htm...
# 3  https://n.news.naver.com/mnews/article/374/000...
# 4  http://www.lawissue.co.kr/view.php?ud=20240326...
# 5  http://www.gameshot.net/common/con_view.php?co...
# 6  https://n.news.naver.com/mnews/article/366/000...
# 7                  https://kbench.com/?q=node/254240
# 8  http://www.newstomato.com/ReadNews.aspx?no=122...
# 9  https://www.ceoscoredaily.com/page/view/202403...
#
#                                          description  \
# 0  라그나로크·리니지 이용자 단체 민원…메이플 사태로 소비자 의식 높아져 게임 운영 과...
# 1  PC게임 리니지와 리니지2, 아이온, 블레이드앤소울, 길드워2, 모바일 게임 리니지...
# 2  파나나스튜디오에는 텐센트코리아의 사업개발이사 등을 역임한 강일모 대표를 중심으로 '...
# 3  파나나스튜디오에는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으...
# 4  이어 파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중...
# 5  파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으로...
# 6  파나나스튜디오는 텐센트코리아에서 사업개발 이사를 역임한 강일모 대표를 중심으로 리니...
# 7  파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으로...
# 8  (사진=웹젠) 파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표...
# 9  파나나스튜디오는 텐센트코리아의 사업개발이사 등을 역임했던 강일모 대표이사를 중심으로...
#
#                            pubDate
# 0  Tue, 26 Mar 2024 14:52:00 +0900
# 1  Tue, 26 Mar 2024 14:46:00 +0900
# 2  Tue, 26 Mar 2024 14:44:00 +0900
# 3  Tue, 26 Mar 2024 14:24:00 +0900
# 4  Tue, 26 Mar 2024 14:24:00 +0900
# 5  Tue, 26 Mar 2024 14:16:00 +0900
# 6  Tue, 26 Mar 2024 14:01:00 +0900
# 7  Tue, 26 Mar 2024 13:46:00 +0900
# 8  Tue, 26 Mar 2024 13:42:00 +0900
# 9  Tue, 26 Mar 2024 13:36:00 +0900

# %% [markdown]
# ## 실습: "리니지 떡상" 두 가지 키워드가 함께 들어간 기사를 검색하도록 쿼리를 구성하세요
