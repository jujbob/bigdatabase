# %%
import sqlite3

# %%
con = sqlite3.connect('naverDB')

# %%
cur = con.cursor()

# %%
cur.execute("CREATE TABLE userTable (id char(4), userName char(15), email char(20), birthYear int)")

# %%
con.commit()

# %%
cur.execute("SELECT * FROM userTable")

# %%
row = cur.fetchone()

# %%
row

# %%
cur.execute("INSERT INTO userTable VALUES('jujbob','ktlim','jujbob@gmail.com',1990)")

# %%
con.commit()

# %%
cur.execute("SELECT * FROM userTable")
row = cur.fetchone()

# %%
row
# Out:
# ('jujbob', 'ktlim', 'jujbob@gmail.com', 1990)

# %% [markdown]
# ## 실습: NaverAPI를 이용해 긍정/부정 키워드 들을 실시간으로 DB에 저장하시오

# %% [markdown]
# ## 1. 키워드 저장을 위한 DB테이블 생성

# %%
cur.execute("CREATE TABLE noKeyword (id char(4), userName char(15), email char(20), birthYear int)")

# %% [markdown]
# ## 2. 검색 데이터 API를 이용해 가져오는 함수 작성

# %%
def get_no_keywords(key):
  num = 0
  #Put your own codes
  return num

# %% [markdown]
# ## 3. 검색된 키워드 양을 저장하기

# %%
while True:
  #Put your own codes
  pos_key = "떡상"
  neg_key = "떡락"
  pos_no = get_no_keywords(pos_key)
  neg_no = get_no_keywords(pos_key)
  cur.execute("INSERT INTO noKeyword VALUES('jujbob','ktlim','jujbob@gmail.com',1990)")
  time.sleep(2)
  if xx:
    break


con.commit()
